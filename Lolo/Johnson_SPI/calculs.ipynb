# %%
import numpy as np
import math
import matplotlib.pyplot as plt
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
numb_of_samples = 1
factor = round(math.pow(2, 15) / numb_of_samples)
hex_val_samples = hex(factor)
print(hex_val_samples)
# Out:
# 0x8000

# %%
hex_val = "66" 
de10_val = int(hex_val, 16) / 100
print(int(hex_val, 16))
samples = 100

std = math.sqrt(de10_val/(samples-1))

std_error = std / math.sqrt(samples)

print("std is " + str(std))
print("std error is " + str(std_error))
# Out:
# 102
# std is 0.10150384378451047
# std error is 0.010150384378451047

# %%
val_to_convert = 256
numb_in_dec = round(math.pow(2,15) / val_to_convert)
print(numb_in_dec)
print(hex(numb_in_dec))
# Out:
# 128
# 0x80

# %%
xpoints = np.array([1, 3, 5, 10])
ypoints = np.array([0.0281, 0.0165, 0.0135, 0.00995])
ypoints_2 = np.array([0.0292,0.0173,0.0147,0.0102])
plt.plot(xpoints, ypoints, label='x error')
plt.plot(xpoints, ypoints_2, label = 'y error')
plt.axhline(y = 0.01, color='red')
plt.xticks(xpoints)
plt.title('Standard Error vs Number of Samples')
plt.xlabel('Number of samples')
plt.ylabel('Standard Error')
plt.legend(loc="upper left")
plt.ylim(0, 0.036)
plt.show()
